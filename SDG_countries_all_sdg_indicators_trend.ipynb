# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df_fig211=pd.read_csv("Copy of Appendix_2_Data_for_Figure_2.1-1.csv")
df_SDG_Global_countries_Index_2022=pd.read_csv("Data_SDG_Global_countries_Index_2022.csv")
df_SDG_Global_countries_specific_sdg_indicators=pd.read_csv("Data_SDG_Global_countries_specific_sdg_indicators.csv")
Data_SDG_Global_countries_all_sdg_indicators_trend=pd.read_csv("Data_SDG_Global_countries_all_sdg_indicators_trend.csv")

df_fig211.shape,df_SDG_Global_countries_Index_2022.shape,df_SDG_Global_countries_specific_sdg_indicators.shape,Data_SDG_Global_countries_all_sdg_indicators_trend.shape
# Out:
# ((147, 12), (193, 3), (193, 3), (3894, 119))

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend.head()
# Out:
#   Country Code ISO3      Country  Year  Population       Region Income Group  \
# 0               AFG  Afghanistan  2000  20779957.0  E_Euro_Asia          LIC
# 1               AFG  Afghanistan  2001  21606992.0  E_Euro_Asia          LIC
# 2               AFG  Afghanistan  2002  22600774.0  E_Euro_Asia          LIC
# 3               AFG  Afghanistan  2003  23680871.0  E_Euro_Asia          LIC
# 4               AFG  Afghanistan  2004  24726689.0  E_Euro_Asia          LIC
#
#    SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  ...  \
# 0             44.8          91.4          33.9          20.3  ...
# 1             45.1          91.4          36.9          20.4  ...
# 2             45.0          91.4          35.9          20.7  ...
# 3             45.3          91.4          37.1          20.9  ...
# 4             45.5          91.4          37.8          22.0  ...
#
#    n_sdg16_cpi  n_sdg16_clabor  n_sdg16_weaponsexp  n_sdg16_rsf  \
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend.columns[24:119]
# Out:
# Index(['n_sdg1_wpc', 'n_sdg1_320pov', 'n_sdg2_undernsh', 'n_sdg2_stunting',
#        'n_sdg2_wasting', 'n_sdg2_obesity', 'n_sdg2_trophic', 'n_sdg2_crlyld',
#        'n_sdg2_snmi', 'n_sdg2_pestexp', 'n_sdg3_matmort', 'n_sdg3_neonat',
#        'n_sdg3_u5mort', 'n_sdg3_tb', 'n_sdg3_hiv', 'n_sdg3_ncds',
#        'n_sdg3_pollmort', 'n_sdg3_traffic', 'n_sdg3_lifee', 'n_sdg3_fertility',
#        'n_sdg3_births', 'n_sdg3_vac', 'n_sdg3_uhc', 'n_sdg3_swb',
#        'n_sdg4_earlyedu', 'n_sdg4_primary', 'n_sdg4_second', 'n_sdg4_literacy',
#        'n_sdg5_familypl', 'n_sdg5_edat', 'n_sdg5_lfpr', 'n_sdg5_parl',
#        'n_sdg6_water', 'n_sdg6_sanita', 'n_sdg6_freshwat', 'n_sdg6_wastewat',
#        'n_sdg6_scarcew', 'n_sdg7_elecac', 'n_sdg7_cleanfuel', 'n_sdg7_co2twh',
#        'n_sdg7_ren', 'n_sdg8_adjgrowth', 'n_sdg8_slavery', 'n_sdg8_accounts',
#        'n_sdg8_unemp', 'n_sdg8_rights', 'n_sdg8_impacc', 'n_sdg9_intuse',
#        'n_sdg9_mobuse', 'n_sdg9_lpi', 'n_sdg9_uni', 'n_sdg9_articles',
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend['Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', 'Denmark',
#        'Djibouti', 'Dominican Republic', 'East and South Asia',
#        'Eastern Europe and Central Asia', 'Ecuador', 'Egypt, Arab Rep.',
#        'El Salvador', 'Estonia', 'Eswatini', 'Ethiopia', 'Fiji',
#        'Finland', 'France', 'Gabon', 'Gambia, The', 'Georgia', 'Germany',
#        'Ghana', 'Greece', 'Guatemala', 'Guinea', 'Guyana', 'Haiti',
# ...

# %%
df_SDG_country_all_sdg_indicators_trend_World=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='World')]
df_SDG_country_all_sdg_indicators_trend_World.head()
# Out:
#      Country Code ISO3 Country  Year  Population Region Income Group  \
# 3806             World   World  2000         NaN    NaN          NaN
# 3807             World   World  2001         NaN    NaN          NaN
# 3808             World   World  2002         NaN    NaN          NaN
# 3809             World   World  2003         NaN    NaN          NaN
# 3810             World   World  2004         NaN    NaN          NaN
#
#       SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  ...  \
# 3806             59.4          59.0          60.9          55.0  ...
# 3807             59.5          58.8          60.9          55.8  ...
# 3808             59.6          58.6          60.4          56.1  ...
# 3809             59.7          58.4          60.3          56.7  ...
# 3810             59.8          58.2          60.5          57.4  ...
#
#       n_sdg16_cpi  n_sdg16_clabor  n_sdg16_weaponsexp  n_sdg16_rsf  \
# ...

# %%
plt.plot(df_SDG_country_all_sdg_indicators_trend_World['Year'],df_SDG_country_all_sdg_indicators_trend_World['SDG Index Score'])

# %%
plt.plot(df_SDG_country_all_sdg_indicators_trend_World['Year'],df_SDG_country_all_sdg_indicators_trend_World['n_sdg10_gini'])

# %%
# plt.plot(df_SDG_country_all_sdg_indicators_trend_World['Year'],df_SDG_country_all_sdg_indicators_trend_World['SDG Index Score'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_World['Year'],df_SDG_country_all_sdg_indicators_trend_World['Goal 13 Score'])

# %%
df_SDG_country_all_sdg_indicators_trend_Nepal=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Nepal')]
df_SDG_country_all_sdg_indicators_trend_Thailand=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Thailand')]
df_SDG_country_all_sdg_indicators_trend_Finland=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Finland')]
df_SDG_country_all_sdg_indicators_trend_China=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='China')]
df_SDG_country_all_sdg_indicators_trend_Albania=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Albania')]
df_SDG_country_all_sdg_indicators_trend_India=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='India')]

# %%
plt.plot(np.diff(df_SDG_country_all_sdg_indicators_trend_Thailand['SDG Index Score']))
# plt.plot(np.diff(df_SDG_country_all_sdg_indicators_trend_India['SDG Index Score']))
plt.plot(np.diff(df_SDG_country_all_sdg_indicators_trend_China['SDG Index Score']))

# %%
plt.plot(df_SDG_country_all_sdg_indicators_trend_India['Year'],df_SDG_country_all_sdg_indicators_trend_India['SDG Index Score'])
# plt.plot(df_SDG_country_all_sdg_indicators_trend_Albania['Year'],df_SDG_country_all_sdg_indicators_trend_Albania['SDG Index Score'])
# plt.plot(df_SDG_country_all_sdg_indicators_trend_China['Year'],df_SDG_country_all_sdg_indicators_trend_China['SDG Index Score'])
# plt.plot(df_SDG_country_all_sdg_indicators_trend_Finland['Year'],df_SDG_country_all_sdg_indicators_trend_Finland['SDG Index Score'])
# plt.plot(df_SDG_country_all_sdg_indicators_trend_Thailand['Year'],df_SDG_country_all_sdg_indicators_trend_Thailand['SDG Index Score'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_Nepal['Year'],df_SDG_country_all_sdg_indicators_trend_Nepal['SDG Index Score'])

# plt.ylim([0,80])

# %%
plt.plot(df_SDG_country_all_sdg_indicators_trend_Albania['Year'],df_SDG_country_all_sdg_indicators_trend_Albania['Goal 13 Score'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_India['Year'],df_SDG_country_all_sdg_indicators_trend_India['Goal 13 Score'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_China['Year'],df_SDG_country_all_sdg_indicators_trend_China['Goal 13 Score'])
# plt.plot(df_SDG_country_all_sdg_indicators_trend_Finland['Year'],df_SDG_country_all_sdg_indicators_trend_Finland['Goal 13 Score'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_Thailand['Year'],df_SDG_country_all_sdg_indicators_trend_Thailand['Goal 13 Score'])

# %%
plt.plot(df_SDG_country_all_sdg_indicators_trend_Albania['Year'],df_SDG_country_all_sdg_indicators_trend_Albania['n_sdg13_co2gcp'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_India['Year'],df_SDG_country_all_sdg_indicators_trend_India['n_sdg13_co2gcp'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_China['Year'],df_SDG_country_all_sdg_indicators_trend_China['n_sdg13_co2gcp'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_Finland['Year'],df_SDG_country_all_sdg_indicators_trend_Finland['n_sdg13_co2gcp'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_World['Year'],df_SDG_country_all_sdg_indicators_trend_World['n_sdg13_co2gcp'])

# %%
plt.plot(df_SDG_country_all_sdg_indicators_trend_Finland['Year'],20-(df_SDG_country_all_sdg_indicators_trend_Finland['n_sdg13_co2gcp']*20/100))
plt.plot(df_SDG_country_all_sdg_indicators_trend_China['Year'],20-(df_SDG_country_all_sdg_indicators_trend_China['n_sdg13_co2gcp']*20/100))
plt.plot(df_SDG_country_all_sdg_indicators_trend_Thailand['Year'],20-(df_SDG_country_all_sdg_indicators_trend_Thailand['n_sdg13_co2gcp']*20/100))
plt.plot(df_SDG_country_all_sdg_indicators_trend_World['Year'],20-(df_SDG_country_all_sdg_indicators_trend_World['n_sdg13_co2gcp']*20/100))

# %%
plt.plot(df_SDG_country_all_sdg_indicators_trend_World['Year'],20-(df_SDG_country_all_sdg_indicators_trend_World['n_sdg13_co2gcp']*20/100))

# %%
# 100*(20-10.994)/20

# %%
# 20-(45.03*20/100)

# %%
df_SDG_country_all_sdg_indicators_trend_Nepal[df_SDG_country_all_sdg_indicators_trend_Nepal.columns[6:24]].corr().dropna(how='all')
# Out:
#                  SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  \
# SDG Index Score         1.000000      0.909747      0.980337      0.991620
# Goal 1 Score            0.909747      1.000000      0.839789      0.911069
# Goal 2 Score            0.980337      0.839789      1.000000      0.964520
# Goal 3 Score            0.991620      0.911069      0.964520      1.000000
# Goal 4 Score            0.982631      0.871489      0.990387      0.964804
# Goal 5 Score            0.945932      0.833889      0.899272      0.947457
# Goal 6 Score            0.992515      0.901322      0.966366      0.991772
# Goal 7 Score            0.847705      0.572137      0.891087      0.840517
# Goal 8 Score            0.682811      0.777966      0.608852      0.709666
# Goal 9 Score            0.945818      0.961133      0.904060      0.940717
# Goal 10 Score           0.892059      0.712423      0.904503      0.853484
# ...

# %%
df_SDG_country_all_sdg_indicators_trend_India[df_SDG_country_all_sdg_indicators_trend_India.columns[6:24]].corr().dropna(how='all')
# Out:
#                  SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  \
# SDG Index Score         1.000000      0.971581      0.931907      0.947255
# Goal 1 Score            0.971581      1.000000      0.879153      0.873601
# Goal 2 Score            0.931907      0.879153      1.000000      0.941425
# Goal 3 Score            0.947255      0.873601      0.941425      1.000000
# Goal 4 Score            0.864135      0.755750      0.900859      0.952784
# Goal 5 Score            0.908304      0.925185      0.839903      0.821636
# Goal 6 Score            0.963315      0.896102      0.940696      0.990319
# Goal 7 Score            0.988753      0.969553      0.900998      0.934570
# Goal 8 Score            0.902920      0.920928      0.798545      0.746241
# Goal 9 Score            0.932864      0.940376      0.787619      0.785689
# Goal 10 Score          -0.782004     -0.683891     -0.843646     -0.895940
# ...

# %%
df_SDG_country_all_sdg_indicators_trend_Finland[['Goal 11 Score','Goal 12 Score','Goal 3 Score']]
# Out:
#       Goal 11 Score  Goal 12 Score  Goal 3 Score
# 1166           91.4           71.3          89.9
# 1167           91.4           71.3          90.0
# 1168           91.4           71.3          90.3
# 1169           91.4           71.3          90.7
# 1170           91.4           71.3          90.8
# 1171           91.4           71.3          91.6
# 1172           91.4           71.3          92.0
# 1173           91.4           71.3          92.0
# 1174           89.8           71.3          92.2
# 1175           89.8           71.3          92.5
# 1176           89.7           71.3          93.2
# 1177           90.1           71.4          93.2
# 1178           89.5           71.4          93.5
# 1179           89.6           71.3          93.6
# 1180           90.7           71.0          93.8
# 1181           90.8           70.8          94.1
# 1182           92.0           70.7          94.3
# 1183           93.7           70.5          94.0
# ...

# %%
df_SDG_country_all_sdg_indicators_trend_Nepal[['Goal 11 Score','Goal 7 Score']].plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(df_SDG_country_all_sdg_indicators_trend_Albania['Year'],df_SDG_country_all_sdg_indicators_trend_Albania['n_sdg3_ncds'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_India['Year'],df_SDG_country_all_sdg_indicators_trend_India['n_sdg3_ncds'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_China['Year'],df_SDG_country_all_sdg_indicators_trend_China['n_sdg3_ncds'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_Finland['Year'],df_SDG_country_all_sdg_indicators_trend_Finland['n_sdg3_ncds'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_World['Year'],df_SDG_country_all_sdg_indicators_trend_World['n_sdg3_ncds'])
