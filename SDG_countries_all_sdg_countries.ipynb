# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df_fig211=pd.read_csv("Copy of Appendix_2_Data_for_Figure_2.1-1.csv")
df_SDG_Global_countries_Index_2022=pd.read_csv("Data_SDG_Global_countries_Index_2022.csv")
df_SDG_Global_countries_specific_sdg_indicators=pd.read_csv("Data_SDG_Global_countries_specific_sdg_indicators.csv")
Data_SDG_Global_countries_all_sdg_indicators_trend=pd.read_csv("Data_SDG_Global_countries_all_sdg_indicators_trend.csv")
Data_SDG_Global_countries_all_sdg_indicators_trend_rd=pd.read_csv("Data_SDG_Global_countries_all_sdg_indicators_trend_raw_data.csv")

df_fig211.shape,df_SDG_Global_countries_Index_2022.shape,df_SDG_Global_countries_specific_sdg_indicators.shape,Data_SDG_Global_countries_all_sdg_indicators_trend.shape,Data_SDG_Global_countries_all_sdg_indicators_trend_rd.shape
# Out:
# ((147, 12), (193, 3), (193, 3), (3894, 119), (4738, 104))

# %%
df_SDG_country_all_sdg_indicators_trend_World=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='World')]
df_SDG_country_all_sdg_indicators_trend_World.head()
# Out:
#      Country Code ISO3 Country  Year  Population Region Income Group  \
# 3806             World   World  2000         NaN    NaN          NaN
# 3807             World   World  2001         NaN    NaN          NaN
# 3808             World   World  2002         NaN    NaN          NaN
# 3809             World   World  2003         NaN    NaN          NaN
# 3810             World   World  2004         NaN    NaN          NaN
#
#       SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  ...  \
# 3806             59.4          59.0          60.9          55.0  ...
# 3807             59.5          58.8          60.9          55.8  ...
# 3808             59.6          58.6          60.4          56.1  ...
# 3809             59.7          58.4          60.3          56.7  ...
# 3810             59.8          58.2          60.5          57.4  ...
#
#       n_sdg16_cpi  n_sdg16_clabor  n_sdg16_weaponsexp  n_sdg16_rsf  \
# ...

# %%
df_SDG_country_all_sdg_indicators_trend_World.columns[20:]
# Out:
# Index(['Goal 14 Score', 'Goal 15 Score', 'Goal 16 Score', 'Goal 17 Score',
#        'n_sdg1_wpc', 'n_sdg1_320pov', 'n_sdg2_undernsh', 'n_sdg2_stunting',
#        'n_sdg2_wasting', 'n_sdg2_obesity', 'n_sdg2_trophic', 'n_sdg2_crlyld',
#        'n_sdg2_snmi', 'n_sdg2_pestexp', 'n_sdg3_matmort', 'n_sdg3_neonat',
#        'n_sdg3_u5mort', 'n_sdg3_tb', 'n_sdg3_hiv', 'n_sdg3_ncds',
#        'n_sdg3_pollmort', 'n_sdg3_traffic', 'n_sdg3_lifee', 'n_sdg3_fertility',
#        'n_sdg3_births', 'n_sdg3_vac', 'n_sdg3_uhc', 'n_sdg3_swb',
#        'n_sdg4_earlyedu', 'n_sdg4_primary', 'n_sdg4_second', 'n_sdg4_literacy',
#        'n_sdg5_familypl', 'n_sdg5_edat', 'n_sdg5_lfpr', 'n_sdg5_parl',
#        'n_sdg6_water', 'n_sdg6_sanita', 'n_sdg6_freshwat', 'n_sdg6_wastewat',
#        'n_sdg6_scarcew', 'n_sdg7_elecac', 'n_sdg7_cleanfuel', 'n_sdg7_co2twh',
#        'n_sdg7_ren', 'n_sdg8_adjgrowth', 'n_sdg8_slavery', 'n_sdg8_accounts',
# ...

# %%
df_SDG_country_all_sdg_indicators_trend_Nepal=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Nepal')]
df_SDG_country_all_sdg_indicators_trend_Thailand=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Thailand')]
df_SDG_country_all_sdg_indicators_trend_Finland=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Finland')]
df_SDG_country_all_sdg_indicators_trend_China=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='China')]
df_SDG_country_all_sdg_indicators_trend_Albania=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Albania')]
df_SDG_country_all_sdg_indicators_trend_India=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='India')]
df_SDG_country_all_sdg_indicators_trend_Mongolia=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Mongolia')]

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend_rd.columns[:20]
# Out:
# Index(['id', 'Country', 'Year', 'Population', 'indexreg', 'sdg1_wpc',
#        'sdg1_320pov', 'sdg1_oecdpov', 'sdg2_undernsh', 'sdg2_stuntihme',
#        'sdg2_wasteihme', 'sdg2_obesity', 'sdg2_trophic', 'sdg2_crlyld',
#        'sdg2_snmi', 'sdg3_matmort', 'sdg3_neonat', 'sdg3_u5mort', 'sdg3_tb',
#        'sdg3_hiv'],
#       dtype='object')

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend_rd.columns[20:]
# Out:
# Index(['sdg3_ncds', 'sdg3_traffic', 'sdg3_lifee', 'sdg3_fertility',
#        'sdg3_births', 'sdg3_vac', 'sdg3_uhc', 'sdg3_swb', 'sdg3_region',
#        'sdg3_incomeg', 'sdg3_smoke', 'sdg4_earlyedu', 'sdg4_primary',
#        'sdg4_second', 'sdg4_literacy', 'sdg4_tertiary', 'sdg4_pisa',
#        'sdg4_socioec', 'sdg4_science', 'sdg5_fplmodel', 'sdg5_edat',
#        'sdg5_lfpr', 'sdg5_parl', 'sdg5_paygap', 'sdg6_water', 'sdg6_sanita',
#        'sdg6_safewat', 'sdg6_safesan', 'sdg7_elecac', 'sdg7_cleanfuel',
#        'sdg7_co2twh', 'sdg7_ren', 'sdg8_accounts', 'sdg8_unemp', 'sdg8_rights',
#        'sdg8_impacc', 'sdg8_empop', 'sdg8_yneet', 'sdg9_intuse', 'sdg9_mobuse',
#        'sdg9_lpi', 'sdg9_articles', 'sdg9_rdex', 'sdg9_rdres', 'sdg9_patents',
#        'sdg9_netacc', 'sdg9_womensci', 'sdg10_gini', 'sdg10_palma',
#        'sdg10_elder', 'sdg11_slums', 'sdg11_pm25', 'sdg11_pipedwat',
#        'sdg11_transport', 'sdg11_rentover', 'sdg12_nprod', 'sdg12_nimport',
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend.columns[2:24].tolist()
# Out:
# ['Year',
#  'Population',
#  'Region',
#  'Income Group',
#  'SDG Index Score',
#  'Goal 1 Score',
#  'Goal 2 Score',
#  'Goal 3 Score',
#  'Goal 4 Score',
#  'Goal 5 Score',
#  'Goal 6 Score',
#  'Goal 7 Score',
#  'Goal 8 Score',
#  'Goal 9 Score',
#  'Goal 10 Score',
#  'Goal 11 Score',
#  'Goal 12 Score',
#  'Goal 13 Score',
#  'Goal 14 Score',
#  'Goal 15 Score',
#  'Goal 16 Score',
#  'Goal 17 Score']

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Year']==2020)&(Data_SDG_Global_countries_all_sdg_indicators_trend['Country'].isin(countries))].T.head(24)
# Out:
#                           42            702        1186          1538  \
# Country Code ISO3          ALB           CHN        FIN           IND
# Country                Albania         China    Finland         India
# Year                      2020          2020       2020          2020
# Population           2877800.0  1439323774.0  5540718.0  1380004385.0
# Region             E_Euro_Asia      E_S_Asia       OECD      E_S_Asia
# Income Group              UMIC          UMIC        HIC          LMIC
# SDG Index Score           71.3          72.3       86.4          60.1
# Goal 1 Score              91.4          97.7       99.8          51.2
# Goal 2 Score              59.9          82.0       64.2          52.0
# Goal 3 Score              83.0          82.4       94.7          63.3
# Goal 4 Score              94.3          99.5       98.1          82.9
# Goal 5 Score              53.2          77.1       91.0          33.9
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Finland')][Data_SDG_Global_countries_all_sdg_indicators_trend.columns[6:24].tolist()]
# Out:
#       SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  Goal 4 Score  \
# 1166             82.0          99.9          67.6          89.9          85.9
# 1167             82.5          99.9          67.0          90.0          94.8
# 1168             82.8          99.9          67.1          90.3          96.7
# 1169             82.6          99.9          66.7          90.7          95.9
# 1170             83.0          99.9          66.8          90.8          96.5
# 1171             83.8          99.9          66.9          91.6          95.9
# 1172             83.6          99.9          66.6          92.0          97.4
# 1173             83.8          99.9          67.0          92.0          98.0
# 1174             84.2          99.9          66.6          92.2          98.4
# 1175             85.1          99.9          66.9          92.5          96.8
# 1176             85.2          99.9          65.6          93.2          98.0
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Thailand')][Data_SDG_Global_countries_all_sdg_indicators_trend.columns[6:24].tolist()]
# Out:
#       SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  Goal 4 Score  \
# 3454             69.1          98.1          57.6          65.8          91.6
# 3455             69.3          98.1          58.2          66.5          91.6
# 3456             69.4          98.1          58.6          66.7          91.6
# 3457             69.5          98.1          58.9          67.3          91.6
# 3458             69.5          98.1          58.7          67.2          91.6
# 3459             69.9          98.1          59.4          70.1          91.6
# 3460             70.1          98.1          59.7          70.4          91.6
# 3461             70.3          98.1          60.4          70.7          91.4
# 3462             70.3          98.1          60.2          71.0          91.1
# 3463             70.7          98.1          59.8          71.4          91.4
# 3464             71.1          98.1          59.7          74.8          90.4
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Finland')][Data_SDG_Global_countries_all_sdg_indicators_trend.columns[6:24].tolist()].corr()
# Out:
#                  SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  \
# SDG Index Score         1.000000     -0.618012     -0.807046      0.974999
# Goal 1 Score           -0.618012      1.000000      0.769650     -0.690581
# Goal 2 Score           -0.807046      0.769650      1.000000     -0.879795
# Goal 3 Score            0.974999     -0.690581     -0.879795      1.000000
# Goal 4 Score            0.656767     -0.312094     -0.501104      0.645246
# Goal 5 Score            0.944820     -0.697256     -0.862671      0.966525
# Goal 6 Score           -0.846784      0.410072      0.594462     -0.859876
# Goal 7 Score            0.869710     -0.814781     -0.895631      0.900139
# Goal 8 Score            0.868702     -0.668345     -0.832881      0.900854
# Goal 9 Score            0.932668     -0.486621     -0.710899      0.876592
# Goal 10 Score           0.036883      0.176024      0.200462     -0.090562
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Slovenia')][Data_SDG_Global_countries_all_sdg_indicators_trend.columns[6:24].tolist()].corr()
# Out:
#                  SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  \
# SDG Index Score         1.000000      0.291843      0.389031      0.966651
# Goal 1 Score            0.291843      1.000000      0.133484      0.363468
# Goal 2 Score            0.389031      0.133484      1.000000      0.322574
# Goal 3 Score            0.966651      0.363468      0.322574      1.000000
# Goal 4 Score            0.345565     -0.032764     -0.012410      0.374943
# Goal 5 Score            0.928749      0.137877      0.372381      0.887470
# Goal 6 Score            0.843273      0.115278      0.243897      0.876500
# Goal 7 Score            0.865835      0.136000      0.336762      0.826344
# Goal 8 Score           -0.065079      0.669035     -0.075380      0.064143
# Goal 9 Score            0.953492      0.486838      0.287814      0.958311
# Goal 10 Score                NaN           NaN           NaN           NaN
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Thailand')][Data_SDG_Global_countries_all_sdg_indicators_trend.columns[6:24].tolist()].corr()
# Out:
#                  SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  \
# SDG Index Score         1.000000      0.918658     -0.208731      0.962874
# Goal 1 Score            0.918658      1.000000     -0.296129      0.906567
# Goal 2 Score           -0.208731     -0.296129      1.000000     -0.122142
# Goal 3 Score            0.962874      0.906567     -0.122142      1.000000
# Goal 4 Score            0.440907      0.348823     -0.474989      0.260681
# Goal 5 Score           -0.358632     -0.405086     -0.242073     -0.312417
# Goal 6 Score            0.973863      0.907541     -0.116768      0.986252
# Goal 7 Score            0.917510      0.810757      0.026613      0.965755
# Goal 8 Score            0.495444      0.546122      0.237758      0.560156
# Goal 9 Score            0.955479      0.880183     -0.308370      0.860957
# Goal 10 Score           0.978331      0.911150     -0.197271      0.963526
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='India')][Data_SDG_Global_countries_all_sdg_indicators_trend.columns[6:24].tolist()].corr()
# Out:
#                  SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  \
# SDG Index Score         1.000000      0.971581      0.931907      0.947255
# Goal 1 Score            0.971581      1.000000      0.879153      0.873601
# Goal 2 Score            0.931907      0.879153      1.000000      0.941425
# Goal 3 Score            0.947255      0.873601      0.941425      1.000000
# Goal 4 Score            0.864135      0.755750      0.900859      0.952784
# Goal 5 Score            0.908304      0.925185      0.839903      0.821636
# Goal 6 Score            0.963315      0.896102      0.940696      0.990319
# Goal 7 Score            0.988753      0.969553      0.900998      0.934570
# Goal 8 Score            0.902920      0.920928      0.798545      0.746241
# Goal 9 Score            0.932864      0.940376      0.787619      0.785689
# Goal 10 Score          -0.782004     -0.683891     -0.843646     -0.895940
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='India')][Data_SDG_Global_countries_all_sdg_indicators_trend.columns[6:24].tolist()]
# Out:
#       SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  Goal 4 Score  \
# 1518             51.6          32.8          47.6          37.8          60.6
# 1519             51.7          32.8          47.7          40.0          60.6
# 1520             51.8          32.8          46.7          40.6          60.5
# 1521             52.2          32.8          46.7          41.9          64.0
# 1522             52.1          32.8          46.2          43.0          64.0
# 1523             52.2          32.8          46.4          44.1          64.0
# 1524             52.8          32.8          47.2          44.9          68.1
# 1525             53.1          32.8          48.0          45.0          72.6
# 1526             53.2          32.8          48.3          46.8          74.3
# 1527             53.0          32.8          48.2          47.2          73.6
# 1528             53.6          32.8          48.6          51.6          73.9
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend_rd[(Data_SDG_Global_countries_all_sdg_indicators_trend_rd['Country']=='India')][Data_SDG_Global_countries_all_sdg_indicators_trend_rd.columns[15:31]]
# Out:
#       sdg3_matmort  sdg3_neonat  sdg3_u5mort  sdg3_tb  sdg3_hiv  sdg3_ncds  \
# 1817         370.0         44.7         91.7    289.0      0.35      25.09
# 1818         354.0         43.3         88.1    288.0      0.28      24.88
# 1819         336.0         41.9         84.5    287.0      0.23      24.56
# 1820         319.0         40.5         81.1    285.0      0.19      23.91
# 1821         303.0         39.1         77.8    282.0      0.16      22.46
# 1822         286.0         37.9         74.4    279.0      0.14      22.49
# 1823         270.0         36.6         71.1    274.0      0.13      22.80
# 1824         255.0         35.4         67.9    268.0      0.11      23.14
# 1825         240.0         34.3         64.6    261.0      0.10      23.35
# 1826         225.0         33.1         61.4    254.0      0.09      23.22
# 1827         210.0         31.8         58.2    247.0      0.08      23.69
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend_rd[(Data_SDG_Global_countries_all_sdg_indicators_trend_rd['Country']=='China')][Data_SDG_Global_countries_all_sdg_indicators_trend_rd.columns[15:31]]
# Out:
#      sdg3_matmort  sdg3_neonat  sdg3_u5mort  sdg3_tb  sdg3_hiv  sdg3_ncds  \
# 805          59.0         21.4         36.7    107.0       1.0      23.02
# 806          55.0         19.9         34.1    104.0       1.0      22.66
# 807          51.0         18.4         31.5    100.0       1.0      22.67
# 808          48.0         16.9         28.8     97.0       1.0      22.68
# 809          46.0         15.3         26.3     94.0       1.0      22.53
# 810          44.0         13.9         24.0     91.0       1.0      21.77
# 811          42.0         12.5         21.9     88.0       1.0      20.69
# 812          40.0         11.3         20.1     85.0       1.0      19.98
# 813          40.0         10.2         18.5     82.0       1.0      19.62
# 814          37.0          9.2         17.0     81.0       1.0      19.29
# 815          36.0          8.4         15.8     76.0       1.0      19.03
# 816          34.0          7.6         14.6     75.0       1.0      18.68
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend_rd[(Data_SDG_Global_countries_all_sdg_indicators_trend_rd['Country']=='Finland')][Data_SDG_Global_countries_all_sdg_indicators_trend_rd.columns[15:31]]
# Out:
#       sdg3_matmort  sdg3_neonat  sdg3_u5mort  sdg3_tb  sdg3_hiv  sdg3_ncds  \
# 1403           6.0          2.5          4.3     12.0       1.0      14.68
# 1404           5.0          2.4          4.2     10.0       1.0      13.78
# 1405           5.0          2.3          4.1      9.9       1.0      13.60
# 1406           5.0          2.2          4.0      8.7       1.0      13.38
# 1407           5.0          2.1          3.9      7.0       1.0      13.38
# 1408           5.0          2.1          3.7      7.4       1.0      12.97
# 1409           4.0          2.0          3.6      6.1       1.0      12.50
# 1410           4.0          1.9          3.5      6.5       1.0      12.52
# 1411           4.0          1.8          3.3      7.2       1.0      12.19
# 1412           4.0          1.8          3.2      8.7       1.0      12.16
# 1413           4.0          1.7          3.0      6.6       1.0      11.98
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend_rd[(Data_SDG_Global_countries_all_sdg_indicators_trend_rd['Country']=='Thailand')][Data_SDG_Global_countries_all_sdg_indicators_trend_rd.columns[15:31]]
