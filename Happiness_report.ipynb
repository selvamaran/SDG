# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df_fig211=pd.read_csv("Copy of Appendix_2_Data_for_Figure_2.1-1.csv")
df_SDG_Global_countries_Index_2022=pd.read_csv("Data_SDG_Global_countries_Index_2022.csv")
df_SDG_Global_countries_specific_sdg_indicators=pd.read_csv("Data_SDG_Global_countries_specific_sdg_indicators.csv")
df_fig211.shape,df_SDG_Global_countries_Index_2022.shape,df_SDG_Global_countries_specific_sdg_indicators.shape
# Out:
# ((147, 12), (193, 3), (193, 3))

# %%
df_fig211.head()
# Out:
#    RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1      Finland            7.821         7.886        7.756
# 1     2      Denmark            7.636         7.710        7.563
# 2     3      Iceland            7.557         7.651        7.464
# 3     4  Switzerland            7.512         7.586        7.437
# 4     5  Netherlands            7.415         7.471        7.359
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
# 3                       2.153                         2.026
# 4                       2.137                         1.945
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# ...

# %%
df_SDG_Global_countries_Index_2022.head()
# Out:
#    Country  2022 SDG Index Score  2022 SDG Index Rank
# 0  Finland                  86.5                  1.0
# 1  Denmark                  85.6                  2.0
# 2   Sweden                  85.2                  3.0
# 3   Norway                  82.3                  4.0
# 4  Austria                  82.3                  5.0

# %%
df_happiness_sdg=df_fig211.merge(df_SDG_Global_countries_Index_2022)
df_happiness_sdg.shape
# Out:
# (111, 14)

# %%
df_happiness_sdg_sdg3=df_SDG_Global_countries_specific_sdg_indicators.merge(df_fig211).merge(df_SDG_Global_countries_Index_2022)
df_happiness_sdg_sdg3.shape
# Out:
# (111, 16)

# %%
df_SDG_Global_countries_specific_sdg_indicators.head()
# Out:
#     id      Country  sdg3_ncds
# 0  AFG  Afghanistan      35.27
# 1  ALB      Albania      11.40
# 2  DZA      Algeria      13.86
# 3  AND      Andorra        NaN
# 4  AGO       Angola      22.25

# %%
df_fig211[['Happiness score','Explained by: Healthy life expectancy','Explained by: Social support','Explained by: GDP per capita']].describe()
# Out:
#        Happiness score  Explained by: Healthy life expectancy  \
# count       146.000000                             146.000000
# mean          5.553575                               0.586171
# std           1.086843                               0.176336
# min           2.404000                               0.000000
# 25%           4.888750                               0.463250
# 50%           5.568500                               0.621500
# 75%           6.305000                               0.719750
# max           7.821000                               0.942000
#
#        Explained by: Social support  Explained by: GDP per capita
# count                    146.000000                    146.000000
# mean                       0.905863                      1.410445
# std                        0.280122                      0.421663
# min                        0.000000                      0.000000
# 25%                        0.732000                      1.095500
# ...

# %%
df_fig211[['Happiness score','Explained by: Healthy life expectancy','Explained by: Social support','Explained by: GDP per capita']].corr()
# Out:
#                                        Happiness score  \
# Happiness score                               1.000000
# Explained by: Healthy life expectancy         0.740260
# Explained by: Social support                  0.777889
# Explained by: GDP per capita                  0.763677
#
#                                        Explained by: Healthy life expectancy  \
# Happiness score                                                     0.740260
# Explained by: Healthy life expectancy                               1.000000
# Explained by: Social support                                        0.666760
# Explained by: GDP per capita                                        0.815386
#
#                                        Explained by: Social support  \
# Happiness score                                            0.777889
# Explained by: Healthy life expectancy                      0.666760
# Explained by: Social support                               1.000000
# ...

# %%
df_happiness_sdg_sdg3[['Happiness score','Explained by: Healthy life expectancy','Explained by: Social support','Explained by: GDP per capita','2022 SDG Index Score']].corr()
# Out:
#                                        Happiness score  \
# Happiness score                               1.000000
# Explained by: Healthy life expectancy         0.757404
# Explained by: Social support                  0.828222
# Explained by: GDP per capita                  0.820229
# 2022 SDG Index Score                          0.792632
#
#                                        Explained by: Healthy life expectancy  \
# Happiness score                                                     0.757404
# Explained by: Healthy life expectancy                               1.000000
# Explained by: Social support                                        0.723927
# Explained by: GDP per capita                                        0.864283
# 2022 SDG Index Score                                                0.903477
#
#                                        Explained by: Social support  \
# Happiness score                                            0.828222
# ...

# %%
df_happiness_sdg_sdg3.head()
# Out:
#     id      Country  sdg3_ncds  RANK  Happiness score  Whisker-high  \
# 0  AFG  Afghanistan      35.27   146            2.404         2.469
# 1  ALB      Albania      11.40    90            5.199         5.321
# 2  DZA      Algeria      13.86    96            5.122         5.215
# 3  ARG    Argentina      15.72    57            5.967         6.090
# 4  ARM      Armenia      19.93    82            5.399         5.519
#
#    Whisker-low  Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0        2.339                       1.263                         0.758
# 1        5.076                       1.718                         1.439
# 2        5.030                       1.744                         1.363
# 3        5.844                       1.891                         1.592
# 4        5.278                       1.654                         1.434
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# ...

# %%
df_happiness_sdg_sdg3.sort_values('Explained by: Social support',ascending=False).head()
# Out:
#      id   Country  sdg3_ncds  RANK  Happiness score  Whisker-high  \
# 41  ISL   Iceland       8.65     3            7.557         7.651
# 31  FIN   Finland       9.60     1            7.821         7.886
# 89  SVN  Slovenia      11.45    22            6.630         6.718
# 25  DNK   Denmark      10.77     2            7.636         7.710
# 75  NOR    Norway       8.69     8            7.365         7.440
#
#     Whisker-low  Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 41        7.464                       2.320                         1.936
# 31        7.756                       2.518                         1.892
# 89        6.542                       1.885                         1.810
# 25        7.563                       2.226                         1.953
# 75        7.290                       1.925                         1.997
#
#     Explained by: Social support  Explained by: Healthy life expectancy  \
# ...

# %%
df_happiness_sdg_sdg3[['Happiness score','Explained by: Healthy life expectancy','Explained by: Social support','Explained by: GDP per capita','2022 SDG Index Score','sdg3_ncds']].corr()
# Out:
#                                        Happiness score  \
# Happiness score                               1.000000
# Explained by: Healthy life expectancy         0.757404
# Explained by: Social support                  0.828222
# Explained by: GDP per capita                  0.820229
# 2022 SDG Index Score                          0.792632
# sdg3_ncds                                    -0.654468
#
#                                        Explained by: Healthy life expectancy  \
# Happiness score                                                     0.757404
# Explained by: Healthy life expectancy                               1.000000
# Explained by: Social support                                        0.723927
# Explained by: GDP per capita                                        0.864283
# 2022 SDG Index Score                                                0.903477
# sdg3_ncds                                                          -0.803024
#
# ...
