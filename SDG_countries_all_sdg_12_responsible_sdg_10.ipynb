# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df_fig211=pd.read_csv("Copy of Appendix_2_Data_for_Figure_2.1-1.csv")
df_SDG_Global_countries_Index_2022=pd.read_csv("Data_SDG_Global_countries_Index_2022.csv")
df_SDG_Global_countries_specific_sdg_indicators=pd.read_csv("Data_SDG_Global_countries_specific_sdg_indicators.csv")
Data_SDG_Global_countries_all_sdg_indicators_trend=pd.read_csv("Data_SDG_Global_countries_all_sdg_indicators_trend.csv")
Data_SDG_Global_countries_all_sdg_indicators_trend_rd=pd.read_csv("Data_SDG_Global_countries_all_sdg_indicators_trend_raw_data.csv")

df_fig211.shape,df_SDG_Global_countries_Index_2022.shape,df_SDG_Global_countries_specific_sdg_indicators.shape,Data_SDG_Global_countries_all_sdg_indicators_trend.shape,Data_SDG_Global_countries_all_sdg_indicators_trend_rd.shape
# Out:
# ((147, 12), (193, 3), (193, 3), (3894, 119), (4738, 104))

# %%
df_SDG_country_all_sdg_indicators_trend_World=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='World')]
df_SDG_country_all_sdg_indicators_trend_World.head()
# Out:
#      Country Code ISO3 Country  Year  Population Region Income Group  \
# 3806             World   World  2000         NaN    NaN          NaN
# 3807             World   World  2001         NaN    NaN          NaN
# 3808             World   World  2002         NaN    NaN          NaN
# 3809             World   World  2003         NaN    NaN          NaN
# 3810             World   World  2004         NaN    NaN          NaN
#
#       SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  ...  \
# 3806             59.4          59.0          60.9          55.0  ...
# 3807             59.5          58.8          60.9          55.8  ...
# 3808             59.6          58.6          60.4          56.1  ...
# 3809             59.7          58.4          60.3          56.7  ...
# 3810             59.8          58.2          60.5          57.4  ...
#
#       n_sdg16_cpi  n_sdg16_clabor  n_sdg16_weaponsexp  n_sdg16_rsf  \
# ...

# %%
df_SDG_country_all_sdg_indicators_trend_World.columns[20:]
# Out:
# Index(['Goal 14 Score', 'Goal 15 Score', 'Goal 16 Score', 'Goal 17 Score',
#        'n_sdg1_wpc', 'n_sdg1_320pov', 'n_sdg2_undernsh', 'n_sdg2_stunting',
#        'n_sdg2_wasting', 'n_sdg2_obesity', 'n_sdg2_trophic', 'n_sdg2_crlyld',
#        'n_sdg2_snmi', 'n_sdg2_pestexp', 'n_sdg3_matmort', 'n_sdg3_neonat',
#        'n_sdg3_u5mort', 'n_sdg3_tb', 'n_sdg3_hiv', 'n_sdg3_ncds',
#        'n_sdg3_pollmort', 'n_sdg3_traffic', 'n_sdg3_lifee', 'n_sdg3_fertility',
#        'n_sdg3_births', 'n_sdg3_vac', 'n_sdg3_uhc', 'n_sdg3_swb',
#        'n_sdg4_earlyedu', 'n_sdg4_primary', 'n_sdg4_second', 'n_sdg4_literacy',
#        'n_sdg5_familypl', 'n_sdg5_edat', 'n_sdg5_lfpr', 'n_sdg5_parl',
#        'n_sdg6_water', 'n_sdg6_sanita', 'n_sdg6_freshwat', 'n_sdg6_wastewat',
#        'n_sdg6_scarcew', 'n_sdg7_elecac', 'n_sdg7_cleanfuel', 'n_sdg7_co2twh',
#        'n_sdg7_ren', 'n_sdg8_adjgrowth', 'n_sdg8_slavery', 'n_sdg8_accounts',
# ...

# %%
plt.plot(df_SDG_country_all_sdg_indicators_trend_World['Year'],df_SDG_country_all_sdg_indicators_trend_World['Goal 10 Score'])

# %%
df_SDG_country_all_sdg_indicators_trend_Nepal=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Nepal')]
df_SDG_country_all_sdg_indicators_trend_Thailand=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Thailand')]
df_SDG_country_all_sdg_indicators_trend_Finland=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Finland')]
df_SDG_country_all_sdg_indicators_trend_China=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='China')]
df_SDG_country_all_sdg_indicators_trend_Albania=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Albania')]
df_SDG_country_all_sdg_indicators_trend_India=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='India')]
df_SDG_country_all_sdg_indicators_trend_Mongolia=Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Mongolia')]

# %%
plt.plot(df_SDG_country_all_sdg_indicators_trend_Finland['Year'],df_SDG_country_all_sdg_indicators_trend_Finland['Goal 10 Score'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_Albania['Year'],df_SDG_country_all_sdg_indicators_trend_Albania['Goal 10 Score'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_India['Year'],df_SDG_country_all_sdg_indicators_trend_India['Goal 10 Score'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_China['Year'],df_SDG_country_all_sdg_indicators_trend_China['Goal 10 Score'])
plt.plot(df_SDG_country_all_sdg_indicators_trend_Thailand['Year'],df_SDG_country_all_sdg_indicators_trend_Thailand['Goal 10 Score'])

# %%
countries=['India','China','Finland','Thailand','Albania','Mongolia']
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Year']==2020)&(Data_SDG_Global_countries_all_sdg_indicators_trend['Country'].isin(countries))][['Country','Goal 10 Score']].sort_values(by='Goal 10 Score')
# Out:
#        Country  Goal 10 Score
# 702      China           34.5
# 1538     India           38.5
# 3474  Thailand           69.7
# 42     Albania           80.3
# 2330  Mongolia           81.1
# 1186   Finland           98.4

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Year']==2020)&(Data_SDG_Global_countries_all_sdg_indicators_trend['Country'].isin(countries))][['Country','n_sdg10_gini']].sort_values(by='n_sdg10_gini')
# Out:
#        Country  n_sdg10_gini
# 702      China          69.0
# 1538     India          76.9
# 3474  Thailand          79.2
# 42     Albania          83.9
# 2330  Mongolia          85.4
# 1186   Finland         100.0

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country']=='Thailand')][['Year','n_sdg10_gini']]
# Out:
#       Year  n_sdg10_gini
# 3454  2000          56.9
# 3455  2001          56.9
# 3456  2002          59.4
# 3457  2003          59.4
# 3458  2004          57.7
# 3459  2005          57.7
# 3460  2006          59.7
# 3461  2007          65.4
# 3462  2008          63.9
# 3463  2009          65.9
# 3464  2010          66.5
# 3465  2011          71.8
# 3466  2012          66.8
# 3467  2013          71.0
# 3468  2014          73.2
# 3469  2015          76.1
# 3470  2016          73.5
# 3471  2017          74.6
# 3472  2018          74.9
# 3473  2019          79.2
# 3474  2020          79.2
# 3475  2021          79.2

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend_rd.columns[:20]
# Out:
# Index(['id', 'Country', 'Year', 'Population', 'indexreg', 'sdg1_wpc',
#        'sdg1_320pov', 'sdg1_oecdpov', 'sdg2_undernsh', 'sdg2_stuntihme',
#        'sdg2_wasteihme', 'sdg2_obesity', 'sdg2_trophic', 'sdg2_crlyld',
#        'sdg2_snmi', 'sdg3_matmort', 'sdg3_neonat', 'sdg3_u5mort', 'sdg3_tb',
#        'sdg3_hiv'],
#       dtype='object')

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend_rd.columns[20:]
# Out:
# Index(['sdg3_ncds', 'sdg3_traffic', 'sdg3_lifee', 'sdg3_fertility',
#        'sdg3_births', 'sdg3_vac', 'sdg3_uhc', 'sdg3_swb', 'sdg3_region',
#        'sdg3_incomeg', 'sdg3_smoke', 'sdg4_earlyedu', 'sdg4_primary',
#        'sdg4_second', 'sdg4_literacy', 'sdg4_tertiary', 'sdg4_pisa',
#        'sdg4_socioec', 'sdg4_science', 'sdg5_fplmodel', 'sdg5_edat',
#        'sdg5_lfpr', 'sdg5_parl', 'sdg5_paygap', 'sdg6_water', 'sdg6_sanita',
#        'sdg6_safewat', 'sdg6_safesan', 'sdg7_elecac', 'sdg7_cleanfuel',
#        'sdg7_co2twh', 'sdg7_ren', 'sdg8_accounts', 'sdg8_unemp', 'sdg8_rights',
#        'sdg8_impacc', 'sdg8_empop', 'sdg8_yneet', 'sdg9_intuse', 'sdg9_mobuse',
#        'sdg9_lpi', 'sdg9_articles', 'sdg9_rdex', 'sdg9_rdres', 'sdg9_patents',
#        'sdg9_netacc', 'sdg9_womensci', 'sdg10_gini', 'sdg10_palma',
#        'sdg10_elder', 'sdg11_slums', 'sdg11_pm25', 'sdg11_pipedwat',
#        'sdg11_transport', 'sdg11_rentover', 'sdg12_nprod', 'sdg12_nimport',
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend_rd[(Data_SDG_Global_countries_all_sdg_indicators_trend_rd['Country']=='Finland')][['Year','sdg10_gini']]
# Out:
#       Year  sdg10_gini
# 1403  2000        27.2
# 1404  2001         NaN
# 1405  2002         NaN
# 1406  2003        27.7
# 1407  2004        27.9
# 1408  2005        27.6
# 1409  2006        28.0
# 1410  2007        28.3
# 1411  2008        27.8
# 1412  2009        27.5
# 1413  2010        27.7
# 1414  2011        27.6
# 1415  2012        27.1
# 1416  2013        27.2
# 1417  2014        26.8
# 1418  2015        27.1
# 1419  2016        27.1
# 1420  2017        27.4
# 1421  2018        27.3
# 1422  2019         NaN
# 1423  2020         NaN
# 1424  2021         NaN
# 1425  2022         NaN

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend_rd[(Data_SDG_Global_countries_all_sdg_indicators_trend_rd['Year']==2018)][['Country','sdg10_gini']].sort_values(by='sdg10_gini').dropna()
# Out:
#               Country  sdg10_gini
# 3767         Slovenia        24.6
# 3744  Slovak Republic        25.0
# 1053   Czech Republic        25.0
# 363           Belarus        25.2
# 2778          Moldova        25.7
# ...               ...         ...
# 1766         Honduras        48.9
# 3284           Panama        49.2
# 846          Colombia        50.4
# 110            Angola        51.3
# 547            Brazil        53.9
#
# [68 rows x 2 columns]

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend_rd[(Data_SDG_Global_countries_all_sdg_indicators_trend_rd['Country']=='Slovenia')][['Year','sdg10_gini','sdg4_pisa']].sort_values(by='Year')
# Out:
#       Year  sdg10_gini  sdg4_pisa
# 3749  2000         NaN        NaN
# 3750  2001         NaN        NaN
# 3751  2002         NaN        NaN
# 3752  2003         NaN        NaN
# 3753  2004        24.8        NaN
# 3754  2005        24.6        NaN
# 3755  2006        24.4        NaN
# 3756  2007        24.4        NaN
# 3757  2008        23.7        NaN
# 3758  2009        24.8        NaN
# 3759  2010        24.9        NaN
# 3760  2011        24.9        NaN
# 3761  2012        25.6    498.667
# 3762  2013        26.2        NaN
# 3763  2014        25.7        NaN
# 3764  2015        25.4    509.333
# 3765  2016        24.8        NaN
# 3766  2017        24.2        NaN
# 3767  2018        24.6    503.667
# 3768  2019         NaN        NaN
# 3769  2020         NaN        NaN
# 3770  2021         NaN        NaN
# 3771  2022         NaN        NaN

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend.columns[2:24].tolist()
# Out:
# ['Year',
#  'Population',
#  'Region',
#  'Income Group',
#  'SDG Index Score',
#  'Goal 1 Score',
#  'Goal 2 Score',
#  'Goal 3 Score',
#  'Goal 4 Score',
#  'Goal 5 Score',
#  'Goal 6 Score',
#  'Goal 7 Score',
#  'Goal 8 Score',
#  'Goal 9 Score',
#  'Goal 10 Score',
#  'Goal 11 Score',
#  'Goal 12 Score',
#  'Goal 13 Score',
#  'Goal 14 Score',
#  'Goal 15 Score',
#  'Goal 16 Score',
#  'Goal 17 Score']

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Year'] ==2018) & ((Data_SDG_Global_countries_all_sdg_indicators_trend['SDG Index Score'] >=80) & (Data_SDG_Global_countries_all_sdg_indicators_trend['SDG Index Score']<82))][['Country','SDG Index Score','Goal 3 Score','Goal 10 Score']]
# Out:
#              Country  SDG Index Score  Goal 3 Score  Goal 10 Score
# 172          Austria             81.7          92.0           92.9
# 1206          France             80.7          91.7           85.6
# 1294         Germany             81.9          93.7           89.1
# 1624         Ireland             80.3          94.4           89.2
# 2834          Poland             80.2          85.1           93.4
# 3384     Switzerland             80.3          96.8           83.4
# 3670  United Kingdom             81.0          92.8           69.0

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Year'] ==2018) & ((Data_SDG_Global_countries_all_sdg_indicators_trend['SDG Index Score'] >=82))][['Country','SDG Index Score','Goal 17 Score','Goal 3 Score','Goal 10 Score']]
# Out:
#       Country  SDG Index Score  Goal 17 Score  Goal 3 Score  Goal 10 Score
# 920   Denmark             85.1           82.8          95.1           98.4
# 1184  Finland             85.9           69.5          94.3           98.4
# 2614   Norway             82.0           95.1          96.8           99.9
# 3362   Sweden             85.1           89.6          95.3           94.0

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Year'] ==2018) & ((Data_SDG_Global_countries_all_sdg_indicators_trend['SDG Index Score'] >=80)& (Data_SDG_Global_countries_all_sdg_indicators_trend['SDG Index Score']<=82))][Data_SDG_Global_countries_all_sdg_indicators_trend.columns[:24]]
# Out:
#      Country Code ISO3         Country  Year  Population Region Income Group  \
# 172                AUT         Austria  2018   8891383.0   OECD          HIC
# 1206               FRA          France  2018  64990512.0   OECD          HIC
# 1294               DEU         Germany  2018  83124413.0   OECD          HIC
# 1624               IRL         Ireland  2018   4818694.0   OECD          HIC
# 2614               NOR          Norway  2018   5337960.0   OECD          HIC
# 2834               POL          Poland  2018  37921585.0   OECD          HIC
# 3384               CHE     Switzerland  2018   8525614.0   OECD          HIC
# 3670               GBR  United Kingdom  2018  67141678.0   OECD          HIC
#
#       SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  ...  \
# 172              81.7          99.3          73.7          92.0  ...
# 1206             80.7          99.7          73.8          91.7  ...
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Year'] ==2018) & ((Data_SDG_Global_countries_all_sdg_indicators_trend['SDG Index Score'] >=80)& (Data_SDG_Global_countries_all_sdg_indicators_trend['SDG Index Score']<=82))][Data_SDG_Global_countries_all_sdg_indicators_trend.columns[:24]].drop(['Income Group','Country Code ISO3','Year','Region'],axis=1)
# Out:
#              Country  Population  SDG Index Score  Goal 1 Score  Goal 2 Score  \
# 172          Austria   8891383.0             81.7          99.3          73.7
# 1206          France  64990512.0             80.7          99.7          73.8
# 1294         Germany  83124413.0             81.9          99.5          72.6
# 1624         Ireland   4818694.0             80.3          99.8          76.2
# 2614          Norway   5337960.0             82.0          99.5          60.4
# 2834          Poland  37921585.0             80.2          99.8          68.1
# 3384     Switzerland   8525614.0             80.3          99.7          70.5
# 3670  United Kingdom  67141678.0             81.0          99.5          68.1
#
#       Goal 3 Score  Goal 4 Score  Goal 5 Score  Goal 6 Score  Goal 7 Score  \
# 172           92.0          98.8          79.2          92.4          84.6
# 1206          91.7          99.6          87.2          89.7          76.4
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend.columns[30:]
# Out:
# Index(['n_sdg2_trophic', 'n_sdg2_crlyld', 'n_sdg2_snmi', 'n_sdg2_pestexp',
#        'n_sdg3_matmort', 'n_sdg3_neonat', 'n_sdg3_u5mort', 'n_sdg3_tb',
#        'n_sdg3_hiv', 'n_sdg3_ncds', 'n_sdg3_pollmort', 'n_sdg3_traffic',
#        'n_sdg3_lifee', 'n_sdg3_fertility', 'n_sdg3_births', 'n_sdg3_vac',
#        'n_sdg3_uhc', 'n_sdg3_swb', 'n_sdg4_earlyedu', 'n_sdg4_primary',
#        'n_sdg4_second', 'n_sdg4_literacy', 'n_sdg5_familypl', 'n_sdg5_edat',
#        'n_sdg5_lfpr', 'n_sdg5_parl', 'n_sdg6_water', 'n_sdg6_sanita',
#        'n_sdg6_freshwat', 'n_sdg6_wastewat', 'n_sdg6_scarcew', 'n_sdg7_elecac',
#        'n_sdg7_cleanfuel', 'n_sdg7_co2twh', 'n_sdg7_ren', 'n_sdg8_adjgrowth',
#        'n_sdg8_slavery', 'n_sdg8_accounts', 'n_sdg8_unemp', 'n_sdg8_rights',
#        'n_sdg8_impacc', 'n_sdg9_intuse', 'n_sdg9_mobuse', 'n_sdg9_lpi',
#        'n_sdg9_uni', 'n_sdg9_articles', 'n_sdg9_rdex', 'n_sdg10_gini',
#        'n_sdg10_palma', 'n_sdg11_slums', 'n_sdg11_pm25', 'n_sdg11_pipedwat',
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Year'] ==2018) & ((Data_SDG_Global_countries_all_sdg_indicators_trend['SDG Index Score'] >=80)& (Data_SDG_Global_countries_all_sdg_indicators_trend['SDG Index Score']<=82))][['Country','n_sdg13_co2gcp', 'n_sdg13_co2import','n_sdg13_co2export']]
# Out:
#              Country  n_sdg13_co2gcp  n_sdg13_co2import  n_sdg13_co2export
# 172          Austria            62.6                0.0               99.6
# 1206          France            75.2               23.0              100.0
# 1294         Germany            54.6                5.6               99.6
# 1624         Ireland            59.3                0.0               99.9
# 2614          Norway            58.3                0.0                0.0
# 2834          Poland            55.6               57.0               99.3
# 3384     Switzerland            78.4                0.0              100.0
# 3670  United Kingdom            71.6               18.5               96.8

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country'] =='Norway') & ((Data_SDG_Global_countries_all_sdg_indicators_trend['SDG Index Score'] >=80)& (Data_SDG_Global_countries_all_sdg_indicators_trend['SDG Index Score']<=82))][Data_SDG_Global_countries_all_sdg_indicators_trend.columns[:24]].drop(['Income Group','Country Code ISO3','Year','Region'],axis=1)
# Out:
#      Country  Population  SDG Index Score  Goal 1 Score  Goal 2 Score  \
# 2603  Norway   4719403.0             80.2          99.6          64.8
# 2604  Norway   4771014.0             80.1          99.6          65.7
# 2605  Norway   4826847.0             80.7          99.6          63.6
# 2606  Norway   4885878.0             80.7          99.6          64.4
# 2607  Norway   4948335.0             80.8          99.8          63.2
# 2608  Norway   5013716.0             81.3          99.7          63.5
# 2609  Norway   5079460.0             81.1          99.7          62.8
# 2610  Norway   5142269.0             81.5          99.6          64.3
# 2611  Norway   5199827.0             81.7          99.5          64.9
# 2612  Norway   5250950.0             81.6          99.3          64.5
# 2614  Norway   5337960.0             82.0          99.5          60.4
#
#       Goal 3 Score  Goal 4 Score  Goal 5 Score  Goal 6 Score  Goal 7 Score  \
# ...

# %%
Data_SDG_Global_countries_all_sdg_indicators_trend[(Data_SDG_Global_countries_all_sdg_indicators_trend['Country'] =='Norway') & ((Data_SDG_Global_countries_all_sdg_indicators_trend['SDG Index Score'] >=80)& (Data_SDG_Global_countries_all_sdg_indicators_trend['SDG Index Score']<=82))][Data_SDG_Global_countries_all_sdg_indicators_trend.columns[:24]].drop(['Country','Population','Income Group','Country Code ISO3','Year','Region'],axis=1).corr().sort_values(by='SDG Index Score')
# Out:
#                  SDG Index Score  Goal 1 Score  Goal 2 Score  Goal 3 Score  \
# Goal 12 Score          -0.888849      0.631632      0.289045     -0.860732
# Goal 14 Score          -0.679057      0.566919      0.058009     -0.630020
# Goal 2 Score           -0.535451     -0.123705      1.000000     -0.445166
# Goal 1 Score           -0.427265      1.000000     -0.123705     -0.435851
# Goal 16 Score          -0.380000      0.247407      0.290007     -0.573001
# Goal 10 Score           0.231471      0.292719     -0.342862      0.247253
# Goal 7 Score            0.475665     -0.505448     -0.040060      0.460208
# Goal 11 Score           0.504952     -0.485964     -0.145606      0.409292
# Goal 4 Score            0.648636      0.060129     -0.182525      0.729548
# Goal 8 Score            0.715275     -0.003591     -0.680609      0.639451
# Goal 15 Score           0.782844     -0.578393     -0.632311      0.771834
# ...
